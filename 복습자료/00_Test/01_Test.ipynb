# %%
# pip install uv
# uv venv .venv
# uv pip install pandas
# un pip install matplotlib
# un pip install numpy
# un pip install ipykernel
# un pip install scikit

# %%
import pandas as pd
import numpy as np
